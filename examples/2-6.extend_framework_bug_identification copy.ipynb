# %% [markdown]
# # Extend Janus-CT To Identify Bugs in the Quantum Circuit
#
# **Author:** Congliang Lang \& Siwei Tan
#
# **Date:** 15/4/2024
#
# Based on "[QuCT: A Framework for Analyzing Quantum Circuit by Extracting Contextual and Topological Features (MICRO 2023][1]"
#
# [1]: https://scholar.google.com/scholar_url?url=https://dl.acm.org/doi/abs/10.1145/3613424.3614274%3Fcasa_token%3DffjIB1hQ4ZwAAAAA:8MajDLrDOC74WoeMf7r7AoQ-koxCa4E1TNqQg3GSDz03xUX6XdE3toNTM-YdM_e4rKEusMceJ6BGJg&hl=zh-CN&sa=T&oi=gsb&ct=res&cd=0&d=11146218754516883150&ei=42YSZpPlFL6s6rQPtt6x6Ac&scisig=AFWwaeYaiu2hyx8HUJ_7Buf9Mwom
#
# The vectorization of Janus-CT can be extended to more downstream tasks. For example, in this notebook, we use Janus-CT to identify the potential bugs in the quantum algorithm implementation. We apply a data driven method that traing a model to predict the error rate

# %%
import sys
sys.path.append('..')
import os
os.chdir("..")
import logging
logging.basicConfig(level=logging.WARN)
import ray
ray.init(log_to_driver=False)

from janusq.data_objects.algorithms import get_algorithms
import random
import seaborn as sns
import numpy as np
from collections import defaultdict
import pandas as pd
import jax.numpy as jnp

from janusq.analysis.vectorization import RandomwalkModel

from janusq.tools.ray_func import map
from janusq.data_objects.backend import LinearBackend
import copy
# Out:
# 2024-04-15 14:48:53,439	WARNING services.py:1996 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67100672 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2024-04-15 14:48:54,610	INFO worker.py:1724 -- Started a local Ray instance.

# %%
algorithms = ['qft', 'hs', 'ising', 'qknn', 'qsvm', 'vqc', 'ghz', 'grover']

# %%
import statistics


def scan(n_qubits, n_steps, n_walks, n_bugs):
    backend = LinearBackend(n_qubits)

    dataset =  get_algorithms(n_qubits, backend, algorithms)
    id2circuit = {
        circuit.name: circuit
        for circuit in dataset
    }

    vec_model = RandomwalkModel(n_steps = n_steps, n_walks = n_walks, backend = backend)
    vecs_per_circuit = vec_model.train(dataset, True, remove_redundancy = False, return_value = True)

    total_vecs = np.vstack(vecs_per_circuit)
    vecs_from = np.hstack( [np.ones(len(vecs), dtype=int) * i for i, vecs in enumerate(vecs_per_circuit)] )

    
    alg2success_num, alg2bug_num, alg2error_num, alg_to_n_identified = defaultdict(int), defaultdict(int),defaultdict(int),defaultdict(int)


    def find_bug(bug_circuit, bug_gate_ids):
        alg_name = bug_circuit.name
        gate_vecs = vec_model.vectorize(bug_circuit)
        gate_to_nearest_circuits = []
        
        for analyzed_vec in gate_vecs:
            dists =  np.sqrt( np.sum(  (total_vecs - analyzed_vec)**2, axis=1 ))
            
            dist_indices = np.argsort(dists)[:3]  
            nearest_dists = dists[dist_indices]
            
            dist_indices = dist_indices[nearest_dists < 10] # TODO experimental
            nearest_dists = dists[dist_indices]
            
           
            nearest_circuits = vecs_from[dist_indices]
            nearest_circuits = set(nearest_circuits.tolist())
            gate_to_nearest_circuits.append(nearest_circuits)
            


        for bug_gate_idx, nearest_circuits in enumerate(gate_to_nearest_circuits):

            neighbor_nearest_circuits = []
            for nearest_circuit_set in gate_to_nearest_circuits[bug_gate_idx-6:bug_gate_idx] + gate_to_nearest_circuits[bug_gate_idx+1: bug_gate_idx+6]: 
                neighbor_nearest_circuits += list(nearest_circuit_set)

            neighbor_mode_nearest_circuit1 = None
            neighbor_mode_nearest_circuit2 = None
            if len(neighbor_nearest_circuits) > 0:
                neighbor_mode_nearest_circuit1 = statistics.mode(neighbor_nearest_circuits)
                neighbor_nearest_circuits = [elm for elm in neighbor_nearest_circuits if elm != neighbor_mode_nearest_circuit1]
                if len(neighbor_nearest_circuits) > 0:
                    neighbor_mode_nearest_circuit2 = statistics.mode(neighbor_nearest_circuits)

            if neighbor_mode_nearest_circuit1 not in nearest_circuits:
                if neighbor_mode_nearest_circuit2 is None:
                    if bug_gate_idx not in bug_gate_ids:
                        alg2error_num[alg_name] += 1
                elif neighbor_mode_nearest_circuit2 not in nearest_circuits:
                    if bug_gate_idx not in bug_gate_ids:
                        alg2error_num[alg_name] += 1
                # else:
                #     success_num += 1
                    
            alg_to_n_identified[alg_name] += 1

        alg2bug_num[alg_name] += len(bug_gate_ids)
        for bug_gate_idx in bug_gate_ids:
            if alg_name not in [algorithms[i] for i in gate_to_nearest_circuits[bug_gate_idx]]:
                alg2success_num[alg_name] += 1

    def construct_negative(circuit, bug_num):
        bug_circuit = copy.deepcopy(circuit)

        bug_start = random.randint(0, max(circuit.n_gates - 1 - bug_num, 1))
        bug_end = bug_start + bug_num
        bug_gate_ids = list(range(bug_start, min(bug_end, circuit.n_gates)))

        for bug_gate_id in bug_gate_ids:
            
            gate = bug_circuit.gates[bug_gate_id]

            name = random.choice(backend.basis_gates) # ['rx', 'ry', 'rz', 'h', 'cz', 'cx']

            params = np.random.random((3,1)) * 2 * np.pi
            params = params.tolist()
            
            qubit1 = random.randint(0, n_qubits - 1)
            qubit2 = random.choice([qubit for qubit in range(n_qubits) if qubit != qubit1])
            qubits = [qubit1, qubit2]
            
            gate['name'] = name
            if name in ('rx', 'ry', 'rz'):
                gate['qubits'] = qubits[:1]
                gate['params'] = params[:1]
                
            elif name in ('cz', 'cx'):
                gate['qubits'] = qubits
                gate['params'] = []
                
            elif name in ('h'):
                gate['qubits'] = qubits[:1]
                gate['params'] = []
                
            elif name in ('u'):
                gate['qubits'] = qubits[:1]
                gate['params'] = params
                
            else:
                logging.error("no such gate")
                return circuit

        bug_circuit.name = bug_circuit.name
        return bug_circuit, bug_gate_ids


    def bug_detect(alg_name, n_qubits):
        circuit_id = f'{alg_name}_{n_qubits}'

        current_circuit = id2circuit[circuit_id]
        bug_circuit, bug_gate_ids = construct_negative(current_circuit, bug_num = n_bugs) 

        find_bug(bug_circuit, bug_gate_ids)


    for alg_name in algorithms:
        bug_detect(alg_name, n_qubits)


    print('bug_size', n_bugs)
    print('alg2success_num=', alg2success_num)
    print('alg2bug_num=', alg2bug_num)
    print('alg2error_num=', alg2error_num)
    print('alg2identify_num=', alg_to_n_identified)
    
    return alg2success_num, alg2bug_num, alg2error_num, alg_to_n_identified

# %%
@ray.remote(max_calls=6)
def scan_remote(n_qubits, n_steps, n_walks, n_bugs):
    return scan(n_qubits, n_steps, n_walks, n_bugs)

# %%
results = {}
qubit_range = list(range(5,8))
for n_qubits in qubit_range:
    for n_steps in range(2, 5):
        n_walks = n_steps * 16
        for n_bugs in range(1, 4):
            key = (n_qubits, n_steps, n_walks, n_bugs)
            
            future = scan_remote.remote(*key)
            results[key] = future

# %%
for key, future in results.items():
    result = ray.get(results[key])
    results[key] = result

# %%
results
# Out:
# {(5,
#   2,
#   32,
#   1): (defaultdict(int,
#               {'qft_5': 1,
#                'hs_5': 1,
#                'ising_5': 1,
#                'qknn_5': 1,
#                'qsvm_5': 1,
#                'vqc_5': 1,
#                'ghz_5': 1,
#                'grover_5': 1}), defaultdict(int,
#               {'qft_5': 1,
#                'hs_5': 1,
#                'ising_5': 1,
#                'qknn_5': 1,
#                'qsvm_5': 1,
#                'vqc_5': 1,
#                'ghz_5': 1,
#                'grover_5': 1}), defaultdict(int,
#               {'qft_5': 3,
#                'hs_5': 1,
#                'qknn_5': 1,
#                'vqc_5': 5,
#                'grover_5': 3}), defaultdict(int,
#               {'qft_5': 109,
#                'hs_5': 17,
#                'ising_5': 25,
#                'qknn_5': 63,
#                'qsvm_5': 34,
#                'vqc_5': 436,
#                'ghz_5': 5,
#                'grover_5': 237})),
#  (5,
#   2,
#   32,
#   2): (defaultdict(int,
#               {'qft_5': 2,
#                'hs_5': 2,
#                'ising_5': 2,
#                'qknn_5': 2,
#                'qsvm_5': 2,
#                'vqc_5': 2,
#                'ghz_5': 2,
#                'grover_5': 2}), defaultdict(int,
#               {'qft_5': 2,
#                'hs_5': 2,
#                'ising_5': 2,
#                'qknn_5': 2,
#                'qsvm_5': 2,
#                'vqc_5': 2,
#                'ghz_5': 2,
#                'grover_5': 2}), defaultdict(int,
#               {'qknn_5': 2, 'vqc_5': 1, 'grover_5': 2}), defaultdict(int,
#               {'qft_5': 124,
#                'hs_5': 17,
#                'ising_5': 25,
#                'qknn_5': 63,
#                'qsvm_5': 34,
#                'vqc_5': 436,
#                'ghz_5': 17,
#                'grover_5': 237})),
#  (5,
#   2,
#   32,
#   3): (defaultdict(int,
#               {'qft_5': 3,
#                'hs_5': 3,
#                'ising_5': 3,
#                'qknn_5': 3,
#                'qsvm_5': 3,
#                'vqc_5': 3,
#                'ghz_5': 3,
#                'grover_5': 3}), defaultdict(int,
#               {'qft_5': 3,
#                'hs_5': 3,
#                'ising_5': 3,
#                'qknn_5': 3,
#                'qsvm_5': 3,
#                'vqc_5': 3,
#                'ghz_5': 3,
#                'grover_5': 3}), defaultdict(int,
#               {'qknn_5': 2}), defaultdict(int, {'qft_5': 115,
#                'hs_5': 17,
#                'ising_5': 25,
#                'qknn_5': 63,
#                'qsvm_5': 34,
#                'vqc_5': 436,
#                'ghz_5': 5,
#                'grover_5': 237})),
#  (5,
#   3,
#   48,
#   1): (defaultdict(int,
#               {'qft_5': 1,
#                'hs_5': 1,
#                'ising_5': 1,
#                'qknn_5': 1,
#                'qsvm_5': 1,
#                'vqc_5': 1,
#                'ghz_5': 1,
#                'grover_5': 1}), defaultdict(int,
#               {'qft_5': 1,
#                'hs_5': 1,
#                'ising_5': 1,
#                'qknn_5': 1,
#                'qsvm_5': 1,
#                'vqc_5': 1,
#                'ghz_5': 1,
#                'grover_5': 1}), defaultdict(int,
#               {'qft_5': 2}), defaultdict(int, {'qft_5': 124,
#                'hs_5': 17,
#                'ising_5': 25,
#                'qknn_5': 63,
#                'qsvm_5': 34,
#                'vqc_5': 436,
#                'ghz_5': 5,
#                'grover_5': 237})),
#  (5,
#   3,
#   48,
#   2): (defaultdict(int,
#               {'qft_5': 2,
#                'hs_5': 2,
#                'ising_5': 2,
#                'qknn_5': 2,
#                'qsvm_5': 2,
#                'vqc_5': 2,
#                'ghz_5': 2,
#                'grover_5': 2}), defaultdict(int,
#               {'qft_5': 2,
#                'hs_5': 2,
#                'ising_5': 2,
#                'qknn_5': 2,
#                'qsvm_5': 2,
#                'vqc_5': 2,
#                'ghz_5': 2,
#                'grover_5': 2}), defaultdict(int,
#               {'qknn_5': 1,
#                'qsvm_5': 1,
#                'vqc_5': 1,
#                'grover_5': 3}), defaultdict(int,
#               {'qft_5': 109,
#                'hs_5': 17,
#                'ising_5': 25,
#                'qknn_5': 63,
#                'qsvm_5': 47,
#                'vqc_5': 433,
#                'ghz_5': 5,
#                'grover_5': 237})),
#  (5,
#   3,
#   48,
#   3): (defaultdict(int,
#               {'qft_5': 3,
#                'hs_5': 3,
#                'ising_5': 3,
#                'qknn_5': 3,
#                'qsvm_5': 3,
#                'vqc_5': 3,
#                'ghz_5': 3,
#                'grover_5': 3}), defaultdict(int,
#               {'qft_5': 3,
#                'hs_5': 3,
#                'ising_5': 3,
#                'qknn_5': 3,
#                'qsvm_5': 3,
#                'vqc_5': 3,
#                'ghz_5': 3,
#                'grover_5': 3}), defaultdict(int,
#               {'qknn_5': 1,
#                'qsvm_5': 1,
#                'vqc_5': 2,
#                'grover_5': 1}), defaultdict(int,
#               {'qft_5': 115,
#                'hs_5': 17,
#                'ising_5': 25,
#                'qknn_5': 63,
#                'qsvm_5': 47,
#                'vqc_5': 436,
#                'ghz_5': 5,
#                'grover_5': 237})),
#  (5,
#   4,
#   64,
#   1): (defaultdict(int,
#               {'qft_5': 1,
#                'hs_5': 1,
#                'ising_5': 1,
#                'qknn_5': 1,
#                'qsvm_5': 1,
#                'vqc_5': 1,
#                'ghz_5': 1,
#                'grover_5': 1}), defaultdict(int,
#               {'qft_5': 1,
#                'hs_5': 1,
#                'ising_5': 1,
#                'qknn_5': 1,
#                'qsvm_5': 1,
#                'vqc_5': 1,
#                'ghz_5': 1,
#                'grover_5': 1}), defaultdict(int,
#               {'qsvm_5': 1, 'grover_5': 1}), defaultdict(int,
#               {'qft_5': 109,
#                'hs_5': 17,
#                'ising_5': 29,
#                'qknn_5': 63,
#                'qsvm_5': 47,
#                'vqc_5': 433,
#                'ghz_5': 5,
#                'grover_5': 242})),
#  (5,
#   4,
#   64,
#   2): (defaultdict(int,
#               {'qft_5': 2,
#                'hs_5': 2,
#                'ising_5': 2,
#                'qknn_5': 2,
#                'qsvm_5': 2,
#                'vqc_5': 2,
#                'ghz_5': 2,
#                'grover_5': 2}), defaultdict(int,
#               {'qft_5': 2,
#                'hs_5': 2,
#                'ising_5': 2,
#                'qknn_5': 2,
#                'qsvm_5': 2,
#                'vqc_5': 2,
#                'ghz_5': 2,
#                'grover_5': 2}), defaultdict(int,
#               {'hs_5': 2, 'qknn_5': 1}), defaultdict(int,
#               {'qft_5': 109,
#                'hs_5': 17,
#                'ising_5': 29,
#                'qknn_5': 63,
#                'qsvm_5': 34,
#                'vqc_5': 436,
#                'ghz_5': 5,
#                'grover_5': 237})),
#  (5,
#   4,
#   64,
#   3): (defaultdict(int,
#               {'qft_5': 3,
#                'hs_5': 3,
#                'ising_5': 3,
#                'qknn_5': 3,
#                'qsvm_5': 3,
#                'vqc_5': 3,
#                'ghz_5': 3,
#                'grover_5': 3}), defaultdict(int,
#               {'qft_5': 3,
#                'hs_5': 3,
#                'ising_5': 3,
#                'qknn_5': 3,
#                'qsvm_5': 3,
#                'vqc_5': 3,
#                'ghz_5': 3,
#                'grover_5': 3}), defaultdict(int,
#               {'qft_5': 1,
#                'qknn_5': 1,
#                'vqc_5': 1,
#                'grover_5': 1}), defaultdict(int,
#               {'qft_5': 115,
#                'hs_5': 17,
#                'ising_5': 25,
#                'qknn_5': 63,
#                'qsvm_5': 34,
#                'vqc_5': 433,
#                'ghz_5': 17,
#                'grover_5': 237})),
#  (6,
#   2,
#   32,
#   1): (defaultdict(int,
#               {'qft_6': 1,
#                'hs_6': 1,
#                'ising_6': 1,
#                'qknn_6': 1,
#                'qsvm_6': 1,
#                'vqc_6': 1,
#                'ghz_6': 1,
#                'grover_6': 1}), defaultdict(int,
#               {'qft_6': 1,
#                'hs_6': 1,
#                'ising_6': 1,
#                'qknn_6': 1,
#                'qsvm_6': 1,
#                'vqc_6': 1,
#                'ghz_6': 1,
#                'grover_6': 1}), defaultdict(int,
#               {'qft_6': 2, 'qknn_6': 4, 'ghz_6': 1}), defaultdict(int,
#               {'qft_6': 200,
#                'hs_6': 21,
#                'ising_6': 31,
#                'qknn_6': 64,
#                'qsvm_6': 42,
#                'vqc_6': 686,
#                'ghz_6': 6,
#                'grover_6': 514})),
#  (6,
#   2,
#   32,
#   2): (defaultdict(int,
#               {'qft_6': 2,
#                'hs_6': 2,
#                'ising_6': 2,
#                'qknn_6': 2,
#                'qsvm_6': 2,
#                'vqc_6': 2,
#                'ghz_6': 2,
#                'grover_6': 2}), defaultdict(int,
#               {'qft_6': 2,
#                'hs_6': 2,
#                'ising_6': 2,
#                'qknn_6': 2,
#                'qsvm_6': 2,
#                'vqc_6': 2,
#                'ghz_6': 2,
#                'grover_6': 2}), defaultdict(int,
#               {'qft_6': 1, 'qknn_6': 6}), defaultdict(int,
#               {'qft_6': 200,
#                'hs_6': 21,
#                'ising_6': 31,
#                'qknn_6': 64,
#                'qsvm_6': 42,
#                'vqc_6': 674,
#                'ghz_6': 21,
#                'grover_6': 539})),
#  (6,
#   2,
#   32,
#   3): (defaultdict(int,
#               {'qft_6': 3,
#                'hs_6': 3,
#                'ising_6': 3,
#                'qknn_6': 3,
#                'qsvm_6': 3,
#                'vqc_6': 3,
#                'ghz_6': 3,
#                'grover_6': 3}), defaultdict(int,
#               {'qft_6': 3,
#                'hs_6': 3,
#                'ising_6': 3,
#                'qknn_6': 3,
#                'qsvm_6': 3,
#                'vqc_6': 3,
#                'ghz_6': 3,
#                'grover_6': 3}), defaultdict(int,
#               {'qft_6': 3, 'ghz_6': 1, 'grover_6': 1}), defaultdict(int,
#               {'qft_6': 206,
#                'hs_6': 21,
#                'ising_6': 36,
#                'qknn_6': 64,
#                'qsvm_6': 42,
#                'vqc_6': 702,
#                'ghz_6': 6,
#                'grover_6': 539})),
#  (6,
#   3,
#   48,
#   1): (defaultdict(int,
#               {'qft_6': 1,
#                'hs_6': 1,
#                'ising_6': 1,
#                'qknn_6': 1,
#                'qsvm_6': 1,
#                'vqc_6': 1,
#                'ghz_6': 1,
#                'grover_6': 1}), defaultdict(int,
#               {'qft_6': 1,
#                'hs_6': 1,
#                'ising_6': 1,
#                'qknn_6': 1,
#                'qsvm_6': 1,
#                'vqc_6': 1,
#                'ghz_6': 1,
#                'grover_6': 1}), defaultdict(int,
#               {'qft_6': 2, 'qknn_6': 2, 'vqc_6': 1}), defaultdict(int,
#               {'qft_6': 203,
#                'hs_6': 21,
#                'ising_6': 36,
#                'qknn_6': 64,
#                'qsvm_6': 42,
#                'vqc_6': 702,
#                'ghz_6': 21,
#                'grover_6': 539})),
#  (6,
#   3,
#   48,
#   2): (defaultdict(int,
#               {'qft_6': 2,
#                'hs_6': 2,
#                'ising_6': 2,
#                'qknn_6': 2,
#                'qsvm_6': 2,
#                'vqc_6': 2,
#                'ghz_6': 2,
#                'grover_6': 2}), defaultdict(int,
#               {'qft_6': 2,
#                'hs_6': 2,
#                'ising_6': 2,
#                'qknn_6': 2,
#                'qsvm_6': 2,
#                'vqc_6': 2,
#                'ghz_6': 2,
#                'grover_6': 2}), defaultdict(int,
#               {'qft_6': 2,
#                'qknn_6': 3,
#                'qsvm_6': 3,
#                'vqc_6': 1,
#                'ghz_6': 1,
#                'grover_6': 3}), defaultdict(int,
#               {'qft_6': 200,
#                'hs_6': 21,
#                'ising_6': 36,
#                'qknn_6': 64,
#                'qsvm_6': 60,
#                'vqc_6': 684,
#                'ghz_6': 6,
#                'grover_6': 539})),
#  (6,
#   3,
#   48,
#   3): (defaultdict(int,
#               {'qft_6': 3,
#                'hs_6': 3,
#                'ising_6': 3,
#                'qknn_6': 3,
#                'qsvm_6': 3,
#                'vqc_6': 3,
#                'ghz_6': 3,
#                'grover_6': 3}), defaultdict(int,
#               {'qft_6': 3,
#                'hs_6': 3,
#                'ising_6': 3,
#                'qknn_6': 3,
#                'qsvm_6': 3,
#                'vqc_6': 3,
#                'ghz_6': 3,
#                'grover_6': 3}), defaultdict(int,
#               {'qft_6': 7,
#                'qknn_6': 1,
#                'qsvm_6': 3,
#                'vqc_6': 4,
#                'ghz_6': 1,
#                'grover_6': 3}), defaultdict(int,
#               {'qft_6': 200,
#                'hs_6': 21,
#                'ising_6': 31,
#                'qknn_6': 64,
#                'qsvm_6': 60,
#                'vqc_6': 690,
#                'ghz_6': 6,
#                'grover_6': 514})),
#  (6,
#   4,
#   64,
#   1): (defaultdict(int,
#               {'qft_6': 1,
#                'hs_6': 1,
#                'ising_6': 1,
#                'qknn_6': 1,
#                'qsvm_6': 1,
#                'vqc_6': 1,
#                'ghz_6': 1,
#                'grover_6': 1}), defaultdict(int,
#               {'qft_6': 1,
#                'hs_6': 1,
#                'ising_6': 1,
#                'qknn_6': 1,
#                'qsvm_6': 1,
#                'vqc_6': 1,
#                'ghz_6': 1,
#                'grover_6': 1}), defaultdict(int,
#               {'qft_6': 1, 'qsvm_6': 2, 'grover_6': 4}), defaultdict(int,
#               {'qft_6': 200,
#                'hs_6': 21,
#                'ising_6': 31,
#                'qknn_6': 64,
#                'qsvm_6': 60,
#                'vqc_6': 698,
#                'ghz_6': 21,
#                'grover_6': 519})),
#  (6,
#   4,
#   64,
#   2): (defaultdict(int,
#               {'qft_6': 2,
#                'hs_6': 2,
#                'ising_6': 2,
#                'qknn_6': 2,
#                'qsvm_6': 2,
#                'vqc_6': 2,
#                'ghz_6': 2,
#                'grover_6': 2}), defaultdict(int,
#               {'qft_6': 2,
#                'hs_6': 2,
#                'ising_6': 2,
#                'qknn_6': 2,
#                'qsvm_6': 2,
#                'vqc_6': 2,
#                'ghz_6': 2,
#                'grover_6': 2}), defaultdict(int,
#               {'qft_6': 4,
#                'qknn_6': 2,
#                'qsvm_6': 4,
#                'vqc_6': 4,
#                'ghz_6': 1}), defaultdict(int,
#               {'qft_6': 206,
#                'hs_6': 21,
#                'ising_6': 31,
#                'qknn_6': 64,
#                'qsvm_6': 60,
#                'vqc_6': 690,
#                'ghz_6': 6,
#                'grover_6': 519})),
#  (6,
#   4,
#   64,
#   3): (defaultdict(int,
#               {'qft_6': 3,
#                'hs_6': 3,
#                'ising_6': 3,
#                'qknn_6': 3,
#                'qsvm_6': 3,
#                'vqc_6': 3,
#                'ghz_6': 3,
#                'grover_6': 3}), defaultdict(int,
#               {'qft_6': 3,
#                'hs_6': 3,
#                'ising_6': 3,
#                'qknn_6': 3,
#                'qsvm_6': 3,
#                'vqc_6': 3,
#                'ghz_6': 3,
#                'grover_6': 3}), defaultdict(int,
#               {'qft_6': 1,
#                'qknn_6': 1,
#                'vqc_6': 4,
#                'ghz_6': 1,
#                'grover_6': 2}), defaultdict(int,
#               {'qft_6': 200,
#                'hs_6': 21,
#                'ising_6': 31,
#                'qknn_6': 64,
#                'qsvm_6': 42,
#                'vqc_6': 680,
#                'ghz_6': 6,
#                'grover_6': 545})),
#  (7,
#   2,
#   32,
#   1): (defaultdict(int,
#               {'qft_7': 1,
#                'hs_7': 1,
#                'ising_7': 1,
#                'qknn_7': 1,
#                'qsvm_7': 1,
#                'vqc_7': 1,
#                'ghz_7': 1,
#                'grover_7': 1}), defaultdict(int,
#               {'qft_7': 1,
#                'hs_7': 1,
#                'ising_7': 1,
#                'qknn_7': 1,
#                'qsvm_7': 1,
#                'vqc_7': 1,
#                'ghz_7': 1,
#                'grover_7': 1}), defaultdict(int,
#               {'qft_7': 1, 'qknn_7': 2, 'vqc_7': 1}), defaultdict(int,
#               {'qft_7': 318,
#                'hs_7': 25,
#                'ising_7': 37,
#                'qknn_7': 90,
#                'qsvm_7': 73,
#                'vqc_7': 770,
#                'ghz_7': 25,
#                'grover_7': 1251})),
#  (7,
#   2,
#   32,
#   2): (defaultdict(int,
#               {'qft_7': 2,
#                'hs_7': 2,
#                'ising_7': 2,
#                'qknn_7': 2,
#                'qsvm_7': 2,
#                'vqc_7': 2,
#                'ghz_7': 2,
#                'grover_7': 2}), defaultdict(int,
#               {'qft_7': 2,
#                'hs_7': 2,
#                'ising_7': 2,
#                'qknn_7': 2,
#                'qsvm_7': 2,
#                'vqc_7': 2,
#                'ghz_7': 2,
#                'grover_7': 2}), defaultdict(int,
#               {'qft_7': 1, 'vqc_7': 3, 'grover_7': 3}), defaultdict(int,
#               {'qft_7': 325,
#                'hs_7': 25,
#                'ising_7': 43,
#                'qknn_7': 92,
#                'qsvm_7': 50,
#                'vqc_7': 824,
#                'ghz_7': 7,
#                'grover_7': 1243})),
#  (7,
#   2,
#   32,
#   3): (defaultdict(int,
#               {'qft_7': 3,
#                'hs_7': 3,
#                'ising_7': 3,
#                'qknn_7': 3,
#                'qsvm_7': 3,
#                'vqc_7': 3,
#                'ghz_7': 3,
#                'grover_7': 3}), defaultdict(int,
#               {'qft_7': 3,
#                'hs_7': 3,
#                'ising_7': 3,
#                'qknn_7': 3,
#                'qsvm_7': 3,
#                'vqc_7': 3,
#                'ghz_7': 3,
#                'grover_7': 3}), defaultdict(int,
#               {'qft_7': 3,
#                'qknn_7': 4,
#                'qsvm_7': 1,
#                'vqc_7': 4,
#                'grover_7': 10}), defaultdict(int,
#               {'qft_7': 310,
#                'hs_7': 25,
#                'ising_7': 43,
#                'qknn_7': 92,
#                'qsvm_7': 73,
#                'vqc_7': 800,
#                'ghz_7': 25,
#                'grover_7': 1251})),
#  (7,
#   3,
#   48,
#   1): (defaultdict(int,
#               {'qft_7': 1,
#                'hs_7': 1,
#                'ising_7': 1,
#                'qknn_7': 1,
#                'qsvm_7': 1,
#                'vqc_7': 1,
#                'ghz_7': 1,
#                'grover_7': 1}), defaultdict(int,
#               {'qft_7': 1,
#                'hs_7': 1,
#                'ising_7': 1,
#                'qknn_7': 1,
#                'qsvm_7': 1,
#                'vqc_7': 1,
#                'ghz_7': 1,
#                'grover_7': 1}), defaultdict(int,
#               {'qft_7': 5, 'qsvm_7': 2, 'vqc_7': 1}), defaultdict(int,
#               {'qft_7': 313,
#                'hs_7': 25,
#                'ising_7': 43,
#                'qknn_7': 90,
#                'qsvm_7': 73,
#                'vqc_7': 899,
#                'ghz_7': 25,
#                'grover_7': 1200})),
#  (7,
#   3,
#   48,
#   2): (defaultdict(int,
#               {'qft_7': 2,
#                'hs_7': 2,
#                'ising_7': 2,
#                'qknn_7': 2,
#                'qsvm_7': 2,
#                'vqc_7': 2,
#                'ghz_7': 2,
#                'grover_7': 2}), defaultdict(int,
#               {'qft_7': 2,
#                'hs_7': 2,
#                'ising_7': 2,
#                'qknn_7': 2,
#                'qsvm_7': 2,
#                'vqc_7': 2,
#                'ghz_7': 2,
#                'grover_7': 2}), defaultdict(int,
#               {'qft_7': 4, 'vqc_7': 4}), defaultdict(int,
#               {'qft_7': 318,
#                'hs_7': 25,
#                'ising_7': 43,
#                'qknn_7': 92,
#                'qsvm_7': 73,
#                'vqc_7': 867,
#                'ghz_7': 7,
#                'grover_7': 1256})),
#  (7,
#   3,
#   48,
#   3): (defaultdict(int,
#               {'qft_7': 3,
#                'hs_7': 3,
#                'ising_7': 3,
#                'qknn_7': 3,
#                'qsvm_7': 3,
#                'vqc_7': 3,
#                'ghz_7': 3,
#                'grover_7': 3}), defaultdict(int,
#               {'qft_7': 3,
#                'hs_7': 3,
#                'ising_7': 3,
#                'qknn_7': 3,
#                'qsvm_7': 3,
#                'vqc_7': 3,
#                'ghz_7': 3,
#                'grover_7': 3}), defaultdict(int,
#               {'qft_7': 2}), defaultdict(int, {'qft_7': 309,
#                'hs_7': 25,
#                'ising_7': 43,
#                'qknn_7': 92,
#                'qsvm_7': 50,
#                'vqc_7': 843,
#                'ghz_7': 25,
#                'grover_7': 1256})),
#  (7,
#   4,
#   64,
#   1): (defaultdict(int,
#               {'qft_7': 1,
#                'hs_7': 1,
#                'ising_7': 1,
#                'qknn_7': 1,
#                'qsvm_7': 1,
#                'vqc_7': 1,
#                'ghz_7': 1,
#                'grover_7': 1}), defaultdict(int,
#               {'qft_7': 1,
#                'hs_7': 1,
#                'ising_7': 1,
#                'qknn_7': 1,
#                'qsvm_7': 1,
#                'vqc_7': 1,
#                'ghz_7': 1,
#                'grover_7': 1}), defaultdict(int,
#               {'qft_7': 2,
#                'qknn_7': 1,
#                'qsvm_7': 7,
#                'vqc_7': 1,
#                'grover_7': 5}), defaultdict(int,
#               {'qft_7': 329,
#                'hs_7': 25,
#                'ising_7': 37,
#                'qknn_7': 92,
#                'qsvm_7': 73,
#                'vqc_7': 843,
#                'ghz_7': 25,
#                'grover_7': 1206})),
#  (7,
#   4,
#   64,
#   2): (defaultdict(int,
#               {'qft_7': 2,
#                'hs_7': 2,
#                'ising_7': 2,
#                'qknn_7': 2,
#                'qsvm_7': 2,
#                'vqc_7': 2,
#                'ghz_7': 2,
#                'grover_7': 2}), defaultdict(int,
#               {'qft_7': 2,
#                'hs_7': 2,
#                'ising_7': 2,
#                'qknn_7': 2,
#                'qsvm_7': 2,
#                'vqc_7': 2,
#                'ghz_7': 2,
#                'grover_7': 2}), defaultdict(int,
#               {'qknn_7': 1}), defaultdict(int, {'qft_7': 309,
#                'hs_7': 25,
#                'ising_7': 37,
#                'qknn_7': 90,
#                'qsvm_7': 50,
#                'vqc_7': 863,
#                'ghz_7': 7,
#                'grover_7': 1216})),
#  (7,
#   4,
#   64,
#   3): (defaultdict(int,
#               {'qft_7': 3,
#                'hs_7': 3,
#                'ising_7': 3,
#                'qknn_7': 3,
#                'qsvm_7': 3,
#                'vqc_7': 3,
#                'ghz_7': 3,
#                'grover_7': 3}), defaultdict(int,
#               {'qft_7': 3,
#                'hs_7': 3,
#                'ising_7': 3,
#                'qknn_7': 3,
#                'qsvm_7': 3,
#                'vqc_7': 3,
#                'ghz_7': 3,
#                'grover_7': 3}), defaultdict(int,
#               {'qknn_7': 2, 'qsvm_7': 1, 'vqc_7': 3}), defaultdict(int,
#               {'qft_7': 306,
#                'hs_7': 25,
#                'ising_7': 37,
#                'qknn_7': 90,
#                'qsvm_7': 73,
#                'vqc_7': 854,
#                'ghz_7': 25,
#                'grover_7': 1200}))}

# %%
alg_to_n_qubit_to_n_success = defaultdict(lambda: defaultdict(int))
alg_to_n_qubit_to_n_bugs = defaultdict(lambda: defaultdict(int))


for key, result in results.items():
    n_qubits, n_steps, n_walks, n_bugs = key

    for alg_name in algorithms:
        alg_name = f'{alg_name}_{n_qubits}'
        alg_to_n_qubit_to_n_success[alg_name][n_qubits] += result[0][alg_name]

    for alg_name in algorithms:
        alg_name = f'{alg_name}_{n_qubits}'
        alg_to_n_qubit_to_n_bugs[alg_name][n_qubits] += result[1][alg_name]

# %%
def combine(dict1, dict2, default_value = 1):
    all_values = []
    new_dict = defaultdict(lambda: defaultdict(lambda: default_value))
    for k1, v1 in dict1.items():
        for k2, v2 in v1.items():
            new_dict[k1][k2] = v2 / dict2[k1][k2]
            all_values.append(v2 / dict2[k1][k2])
    
    return new_dict, np.array(all_values)

# %%
alg2n_qubit2success_rate, all_values = combine(alg_to_n_qubit_to_n_success, alg_to_n_qubit_to_n_bugs)
alg2n_qubit2success_rate
# , np.mean(all_values)
# Out:
# defaultdict(<function __main__.combine.<locals>.<lambda>()>,
#             {'qft_5': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {5: 1.0}),
#              'hs_5': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {5: 1.0}),
#              'ising_5': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {5: 1.0}),
#              'qknn_5': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {5: 1.0}),
#              'qsvm_5': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {5: 1.0}),
#              'vqc_5': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {5: 1.0}),
#              'ghz_5': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {5: 1.0}),
#              'grover_5': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {5: 1.0}),
#              'qft_6': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {6: 1.0}),
#              'hs_6': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {6: 1.0}),
#              'ising_6': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {6: 1.0}),
#              'qknn_6': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {6: 1.0}),
#              'qsvm_6': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {6: 1.0}),
#              'vqc_6': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {6: 1.0}),
#              'ghz_6': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {6: 1.0}),
#              'grover_6': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {6: 1.0}),
#              'qft_7': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {7: 1.0}),
#              'hs_7': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {7: 1.0}),
#              'ising_7': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {7: 1.0}),
#              'qknn_7': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {7: 1.0}),
#              'qsvm_7': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {7: 1.0}),
#              'vqc_7': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {7: 1.0}),
#              'ghz_7': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {7: 1.0}),
#              'grover_7': defaultdict(<function __main__.combine.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {7: 1.0})})

# %%
data = np.zeros((len(qubit_range) , len(algorithms)))

for r_i, n_qubits in enumerate(qubit_range):
    for c_i, alg_name in enumerate(algorithms):
        alg_name = f'{alg_name}_{n_qubits}'
        data[r_i][c_i] = alg2n_qubit2success_rate[alg_name][n_qubits]

df = pd.DataFrame(data, index=qubit_range, columns=algorithms)
fig = sns.heatmap(data=df,cmap='OrRd')
